# %%
#필요한 라이브리
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

# %%
# Load Data
data = pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
data = data.drop(columns=['Outcome'])
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
X = data.drop('BMI', axis=1).values
y = data['BMI'].values.astype(np.float32)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
X
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ..., -0.69289057,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.69289057,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -0.69289057,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ...,  0.27959377,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.69289057,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.69289057,
#         -0.47378505, -0.87137393]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# TensorDataset으로 래핑
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)  # y를 2D 텐서로 변환
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)  # y를 2D 텐서로 변환

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32)
y_test_tensor.shape
# Out:
# torch.Size([231, 1])

# %%
class diabetesDense(nn.Module):
    def __init__(self):
        super(diabetesDense, self).__init__()
        self.fc1 = nn.Linear(7, 16)
        self.fc2 = nn.Linear(16, 32)
        self.fc3 = nn.Linear(32, 32)
        self.fc4 = nn.Linear(32, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# Initialize the model, loss function, and optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = diabetesDense().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
model.train()
train_losses = []
epochs = 60
for epoch in range(epochs):
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        output = model(X_batch)
        loss = criterion(output, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    train_losses.append(total_loss / len(train_loader))
    print(f"Epoch {epoch+1}, Loss: {total_loss / len(train_loader):.4f}")
# Out:
# Epoch 1, Loss: 1074.2070
# Epoch 2, Loss: 1055.7622
# Epoch 3, Loss: 1015.5773
# Epoch 4, Loss: 931.8431
# Epoch 5, Loss: 759.4605
# Epoch 6, Loss: 491.3087
# Epoch 7, Loss: 212.2989
# Epoch 8, Loss: 93.3348
# Epoch 9, Loss: 82.0654
# Epoch 10, Loss: 72.2422
# Epoch 11, Loss: 68.0290
# Epoch 12, Loss: 64.4837
# Epoch 13, Loss: 61.1768
# Epoch 14, Loss: 59.0966
# Epoch 15, Loss: 57.2468
# Epoch 16, Loss: 55.3207
# Epoch 17, Loss: 54.1628
# Epoch 18, Loss: 52.6509
# Epoch 19, Loss: 51.3480
# Epoch 20, Loss: 50.4355
# Epoch 21, Loss: 49.5046
# Epoch 22, Loss: 48.6743
# Epoch 23, Loss: 47.7269
# Epoch 24, Loss: 46.8972
# Epoch 25, Loss: 46.7849
# Epoch 26, Loss: 45.6230
# Epoch 27, Loss: 45.1836
# Epoch 28, Loss: 44.5736
# Epoch 29, Loss: 43.9324
# Epoch 30, Loss: 43.8597
# Epoch 31, Loss: 43.2882
# Epoch 32, Loss: 42.5555
# Epoch 33, Loss: 42.5615
# Epoch 34, Loss: 41.8994
# Epoch 35, Loss: 41.6452
# Epoch 36, Loss: 41.2123
# Epoch 37, Loss: 41.0977
# Epoch 38, Loss: 40.6483
# Epoch 39, Loss: 40.3916
# Epoch 40, Loss: 40.1801
# Epoch 41, Loss: 39.9453
# Epoch 42, Loss: 39.7406
# Epoch 43, Loss: 39.5316
# Epoch 44, Loss: 39.3274
# Epoch 45, Loss: 38.9618
# Epoch 46, Loss: 38.7367
# Epoch 47, Loss: 39.0111
# Epoch 48, Loss: 38.4408
# Epoch 49, Loss: 38.1818
# Epoch 50, Loss: 38.2778
# Epoch 51, Loss: 38.1769
# Epoch 52, Loss: 38.1927
# Epoch 53, Loss: 38.0378
# Epoch 54, Loss: 37.6512
# Epoch 55, Loss: 37.5036
# Epoch 56, Loss: 37.8984
# Epoch 57, Loss: 37.4782
# Epoch 58, Loss: 37.3763
# Epoch 59, Loss: 37.2302
# Epoch 60, Loss: 37.0703

# %%
# 평가
model.eval()
preds, actuals = [], []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(device)
        outputs = model(X_batch).cpu().numpy()
        preds.extend(outputs)
        actuals.extend(y_batch.numpy())

mse = mean_squared_error(actuals, preds)
r2_score = r2_score(actuals, preds)
print(f"R^2 Score: {r2_score:.4f}")
print(f"Test MSE: {mse:.4f}")
# Out:
# R^2 Score: 0.1953
# Test MSE: 57.5365

# %%
import matplotlib.pyplot as plt
# Plot the loss and accuracy
plt.figure(figsize=(12, 5))

# Plot loss
plt.plot(train_losses, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
