# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

# %%
# Load Data
data = pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
data = data.drop(columns=['Outcome'])
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# 25%     27.300000                  0.243750   24.000000
# 50%     32.000000                  0.372500   29.000000
# 75%     36.600000                  0.626250   41.000000
# max     67.100000                  2.420000   81.000000

# %%
X = data.drop('BMI', axis=1).values
y = data['BMI'].values.astype(np.float32)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
X
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ..., -0.69289057,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.69289057,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -0.69289057,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ...,  0.27959377,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.69289057,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.69289057,
#         -0.47378505, -0.87137393]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# TensorDataset으로 래핑
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)  # y를 2D 텐서로 변환
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)  # y를 2D 텐서로 변환

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32)
y_test_tensor.shape
# Out:
# torch.Size([231, 1])

# %%
class RegressionModel(nn.Module):
    def __init__(self):
        super(RegressionModel, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(7, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.model(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = RegressionModel().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
model.train()
train_losses = []
epochs = 60
for epoch in range(epochs):
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        output = model(X_batch)
        loss = criterion(output, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    train_losses.append(total_loss / len(train_loader))
    print(f"Epoch {epoch+1}, Loss: {total_loss / len(train_loader):.4f}")
# Out:
# Epoch 1, Loss: 1068.7424
# Epoch 2, Loss: 1045.7423
# Epoch 3, Loss: 998.9034
# Epoch 4, Loss: 930.4286
# Epoch 5, Loss: 821.6734
# Epoch 6, Loss: 680.2739
# Epoch 7, Loss: 516.8193
# Epoch 8, Loss: 357.6518
# Epoch 9, Loss: 229.1838
# Epoch 10, Loss: 146.8665
# Epoch 11, Loss: 111.1872
# Epoch 12, Loss: 94.4598
# Epoch 13, Loss: 86.2361
# Epoch 14, Loss: 82.0354
# Epoch 15, Loss: 77.9635
# Epoch 16, Loss: 75.2083
# Epoch 17, Loss: 72.3104
# Epoch 18, Loss: 69.6665
# Epoch 19, Loss: 67.3961
# Epoch 20, Loss: 66.3113
# Epoch 21, Loss: 63.5350
# Epoch 22, Loss: 61.7510
# Epoch 23, Loss: 60.0090
# Epoch 24, Loss: 58.9123
# Epoch 25, Loss: 57.7071
# Epoch 26, Loss: 56.2872
# Epoch 27, Loss: 55.1173
# Epoch 28, Loss: 53.7343
# Epoch 29, Loss: 52.4532
# Epoch 30, Loss: 51.4589
# Epoch 31, Loss: 50.5402
# Epoch 32, Loss: 49.9349
# Epoch 33, Loss: 49.0751
# Epoch 34, Loss: 47.5704
# Epoch 35, Loss: 46.8249
# Epoch 36, Loss: 46.1316
# Epoch 37, Loss: 45.2515
# Epoch 38, Loss: 44.6714
# Epoch 39, Loss: 44.4077
# Epoch 40, Loss: 43.3428
# Epoch 41, Loss: 42.5535
# Epoch 42, Loss: 41.9790
# Epoch 43, Loss: 41.2995
# Epoch 44, Loss: 40.6158
# Epoch 45, Loss: 40.3598
# Epoch 46, Loss: 39.7882
# Epoch 47, Loss: 39.4923
# Epoch 48, Loss: 39.2118
# Epoch 49, Loss: 38.9791
# Epoch 50, Loss: 38.6084
# Epoch 51, Loss: 38.5433
# Epoch 52, Loss: 37.4749
# Epoch 53, Loss: 37.1896
# Epoch 54, Loss: 36.6810
# Epoch 55, Loss: 36.5235
# Epoch 56, Loss: 36.1781
# Epoch 57, Loss: 36.0084
# Epoch 58, Loss: 35.7692
# Epoch 59, Loss: 35.4550
# Epoch 60, Loss: 35.4932

# %%
# 평가
model.eval()
preds, actuals = [], []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(device)
        outputs = model(X_batch).cpu().numpy()
        preds.extend(outputs)
        actuals.extend(y_batch.numpy())

mse = mean_squared_error(actuals, preds)
r2_score = r2_score(actuals, preds)
print(f"R^2 Score: {r2_score:.4f}")
print(f"Test MSE: {mse:.4f}")
# Out:
# R^2 Score: 0.1688
# Test MSE: 59.4315

# %%
import matplotlib.pyplot as plt
# Plot the loss and accuracy
plt.figure(figsize=(12, 5))

# Plot loss
plt.plot(train_losses, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
